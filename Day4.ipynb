# %% [markdown]
# Day 8: Data Types (numeric, boolean, string, lists, tuple, sets, dictionary)
# Day 9:

# %%
a=10
b=5.4
print(a,type(a))
print(b,type(b))
# Out:
# 10 <class 'int'>
# 5.4 <class 'float'>

# %%
a=float(10)
b=int(5.4)
print(a,type(a))
print(b,type(b))
# Out:
# 10.0 <class 'float'>
# 5 <class 'int'>

# %%
a=2+4j
b=3+7j
c=a+b
print(c,type(c))
# Out:
# (5+11j) <class 'complex'>

# %%
flag=True
print(type(flag))
# Out:
# <class 'bool'>

# %%
flag=8<5
print(flag,type(flag))
# Out:
# False <class 'bool'>

# %%
#
str="My world is beautiful"
print(len(str))
# Out:
# 21

# %%
s1="Hello "
s2="World!!!"
s=s1+s2
print(s)

s5=s*3
print(s5)
# Out:
# Hello World!!!
# Hello World!!!Hello World!!!Hello World!!!

# %%
s1='5' #number in single quotes is considered as string
s2='6'
s=s1+s2
print(s)

s5=s1*3
print(s5)
# Out:
# 56
# 555
